# %%
# 1. 라이브러리 로딩
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 2. 데이터셋 로딩 (Titanic 또는 사용자 CSV)
df = sns.load_dataset('titanic')

# 3. 데이터 전처리: 결측치 제거
df_clean = df[['age', 'fare', 'survived']].dropna()

# 4. 상관계수 분석 (Pearson 상관계수)
correlation_matrix = df_clean.corr()
print("📌 상관계수:\n", correlation_matrix)

# 5. Heatmap 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# 6. 회귀 분석: 나이 vs 요금 (fare)
sns.lmplot(x='age', y='fare', data=df_clean, height=5, aspect=1.5)
plt.title('Age vs Fare: Regression Line')
plt.show()

# 7. 회귀 분석: 나이와 생존 여부
sns.lmplot(x='age', y='survived', data=df_clean, logistic=True)
plt.title('Age vs Survival (Logistic Regression View)')
plt.show()
# Out:
# 📌 상관계수:
#                 age      fare  survived
# age       1.000000  0.096067 -0.077221
# fare      0.096067  1.000000  0.268189
# survived -0.077221  0.268189  1.000000
